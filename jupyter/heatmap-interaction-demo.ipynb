# %%
import polars as pl

from lpm_plot import plot_heatmap

# %%
heatmap_df = pl.read_parquet("../tests/resources/demo-heatmap-df.parquet")
all_data = pl.read_parquet(
    "../tests/resources/demo-detail-df.parquet"
)  # 0.1% of data used

# %%
plot_heatmap(heatmap_df, all_data, interactive=True)
# Out:
# alt.VConcatChart(...)
