# %%
import polars as pl

from lpm_plot import plot_marginal_numerical_categorical

# %%
observed_df = pl.read_csv("../tests/resources/num-cat-observed.csv")
synthetic_df = pl.read_csv("../tests/resources/num-cat-synthetic.csv")

# %%
plot_marginal_numerical_categorical(
    observed_df, synthetic_df, "class", "data", 30, jitter=True
)
# Out:
# alt.Chart(...)

# %%
plot_marginal_numerical_categorical(observed_df, synthetic_df, "class", "data", 30)
# Out:
# alt.Chart(...)
