# %%
import polars as pl

from lpm_plot import plot_marginal_numerical_numerical

# %%
x = "foo"
y = "bar"

observed_df = pl.DataFrame({x: [1, 2, 3, 4, 5], y: [2, 5, 3, 8, 7]})
synthetic_df = pl.DataFrame({x: [3, 1, 8, 3, 1], y: [1, 5, 4, 7, 6]})
print(observed_df)
# Out:
# shape: (5, 2)
# ┌─────┬─────┐
# │ foo ┆ bar │
# │ --- ┆ --- │
# │ i64 ┆ i64 │
# ╞═════╪═════╡
# │ 1   ┆ 2   │
# │ 2   ┆ 5   │
# │ 3   ┆ 3   │
# │ 4   ┆ 8   │
# │ 5   ┆ 7   │
# └─────┴─────┘

# %%
plot_marginal_numerical_numerical(observed_df, synthetic_df, x, y)
# Out:
# alt.Chart(...)
